# %% [markdown]
# <a href="https://colab.research.google.com/github/Helyousfi/Neural-Networks/blob/main/MobileNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename = 'image_data//image.jpg'

# %% [markdown]
# ###First Image to load an image

# %%
from IPython.display import Image 
Image(filename = filename, width = 224, height = 224)

# %% [markdown]
# ### Second method

# %%
from keras.preprocessing import image
img = image.load_img(filename, target_size = (244, 244))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# ###Third method to load an image

# %%
import cv2 
img = cv2.imread(filename)

# %%
plt.imshow(img) # BGR not RGB

# %% [markdown]
# ###Fourth method to load an image

# %%
from PIL import Image
img = Image.open(filename)
img = img.resize((244,244))
plt.imshow(img)

# %% [markdown]
# ### Load the deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %% [markdown]
# ### Preprocessing of the image

# %%
from keras.preprocessing import image
img = image.load_img(filename, target_size = (224, 224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis = 0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
type(final_image)
# Out:
# numpy.ndarray

# %%
predictions = mobile.predict(final_image)

# %%
from keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02115641', 'dingo', 0.34264505), ('n02422699', 'impala', 0.12016863), ('n02117135', 'hyena', 0.07558679), ('n02129165', 'lion', 0.06970743), ('n02423022', 'gazelle', 0.056588892)]]
